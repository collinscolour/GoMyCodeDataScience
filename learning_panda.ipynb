# %% [markdown]
# <a href="https://colab.research.google.com/github/collinscolour/GoMyCodeDataScience/blob/main/learning_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# first import the libary panda

# %%
import pandas as pd

df= pd.read_csv('Loan_prediction_dataset.csv')

#get data from the top
print(df.head(2))

#get data from the bottom
#print(df.tail(2))
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
# ...

# %% [markdown]
# to get the column

# %%
print(df.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# read a specific columns

# %%
print(df[['Self_Employed','ApplicantIncome']])
# Out:
#     Self_Employed  ApplicantIncome
# 0              No             5849
# 1              No             4583
# 2             Yes             3000
# 3              No             2583
# 4              No             6000
# ..            ...              ...
# 609            No             2900
# 610            No             4106
# 611            No             8072
# 612            No             7583
# 613           Yes             4583
#
# [614 rows x 2 columns]

# %% [markdown]
# get rows

# %%
print(df.iloc[0:3])
for index, row in df.iterrows():
  print(index, row['Loan_ID'])

# %%
print(df)
x = df.loc[df['Gender'] == 'mumu']
print(x)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.sort_values(['Loan_ID','ApplicantIncome' ], ascending= [0,0])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 613  LP002990  Female      No          0      Graduate           Yes
# 612  LP002984    Male     Yes          2      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 4    LP001008    Male      No          0      Graduate            No
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 1    LP001003    Male     Yes          1      Graduate            No
# 0    LP001002    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#this is for mean , sd
df.describe

# %%
df['total']= df['ApplicantIncome'] + df['CoapplicantIncome'] + df['LoanAmount'] + df['Loan_Amount_Term']
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#to drop a column2
df = df.drop(columns=['total'])
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#another way to get the total
df['Total'] = df.iloc[:,6:10].sum(axis=1)
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = df.drop(columns=['total', 'Total'])
print(df)

# %%
new_df= df.loc[(df['Gender'] == 'Male') & (df['Married'] == 'No')]
print(new_df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 15   LP001032   Male      No          0      Graduate            No
# 16   LP001034   Male      No          1  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 579  LP002888   Male      No          0      Graduate           NaN
# 581  LP002893   Male      No          0      Graduate            No
# 595  LP002940   Male      No          0  Not Graduate            No
# 597  LP002943   Male      No        NaN      Graduate            No
# 603  LP002958   Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...
